# %%
'''10) Data Visualization III
Download the Iris flower dataset or any other dataset into a DataFrame. (e.g.,
https://archive.ics.uci.edu/ml/datasets/Iris ). Scan the dataset and give the inference as:
1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
2. Create a histogram for each feature in the dataset to illustrate the feature distributions.
3. Create a boxplot for each feature in the dataset.
4. Compare distributions and identify outliers.'''

# %%
import pandas as pd

# %%
df=pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["SepalLengthCm"])
plt.show()

# %%
plt.hist(df["SepalWidthCm"])
plt.show()

# %%
plt.hist(df["PetalLengthCm"])
plt.show()

# %%
plt.hist(df["PetalWidthCm"])
plt.show()

# %%
plt.hist(df["Species"])
plt.show()

# %%
df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
plt.boxplot(df["SepalLengthCm"])
plt.show()

# %%
plt.boxplot(df["SepalWidthCm"])
plt.show()

# %%
plt.boxplot(df["PetalLengthCm"])
plt.show()

# %%
plt.boxplot(df["PetalWidthCm"])
plt.show()

# %%
df["Species"]=df["Species"].replace({"Iris-setosa":1,"Iris-versicolor":2,"Iris-virginica":3})
# Out:
# C:\Users\Sayali Kate\AppData\Local\Temp\ipykernel_25860\1688767412.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Species"]=df["Species"].replace({"Iris-setosa":1,"Iris-versicolor":2,"Iris-virginica":3})

# %%
plt.boxplot(df["Species"])
plt.show()

# %%
plt.hist(df['SepalLengthCm'], edgecolor='black')
plt.hist(df['SepalWidthCm'], edgecolor='blue')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Comparison of Sepal Length and Sepal Width Distributions')
# Out:
# Text(0.5, 1.0, 'Comparison of Sepal Length and Sepal Width Distributions')

# %%
plt.hist(df['PetalLengthCm'], edgecolor='black')
plt.hist(df['PetalWidthCm'], edgecolor='blue')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Comparison of Sepal Length and Sepal Width Distributions')
# Out:
# Text(0.5, 1.0, 'Comparison of Sepal Length and Sepal Width Distributions')
