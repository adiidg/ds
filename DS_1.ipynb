# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.sample(13)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 109           7.2          3.6           6.1          2.5   virginica
# 45            4.8          3.0           1.4          0.3      setosa
# 125           7.2          3.2           6.0          1.8   virginica
# 97            6.2          2.9           4.3          1.3  versicolor
# 108           6.7          2.5           5.8          1.8   virginica
# 13            4.3          3.0           1.1          0.1      setosa
# 30            4.8          3.1           1.6          0.2      setosa
# 138           6.0          3.0           4.8          1.8   virginica
# 42            4.4          3.2           1.3          0.2      setosa
# 144           6.7          3.3           5.7          2.5   virginica
# 90            5.5          2.6           4.4          1.2  versicolor
# 126           6.2          2.8           4.8          1.8   virginica
# ...

# %%
df[12:21]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 12           4.8          3.0           1.4          0.1  setosa
# 13           4.3          3.0           1.1          0.1  setosa
# 14           5.8          4.0           1.2          0.2  setosa
# 15           5.7          4.4           1.5          0.4  setosa
# 16           5.4          3.9           1.3          0.4  setosa
# 17           5.1          3.5           1.4          0.3  setosa
# 18           5.7          3.8           1.7          0.3  setosa
# 19           5.1          3.8           1.5          0.3  setosa
# 20           5.4          3.4           1.7          0.2  setosa

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df[['sepal_length','petal_length','species']]
# Out:
#      sepal_length  petal_length    species
# 0             5.1           1.4     setosa
# 1             4.9           1.4     setosa
# 2             4.7           1.3     setosa
# 3             4.6           1.5     setosa
# 4             5.0           1.4     setosa
# ..            ...           ...        ...
# 145           6.7           5.2  virginica
# 146           6.3           5.0  virginica
# 147           6.5           5.2  virginica
# 148           6.2           5.4  virginica
# 149           5.9           5.1  virginica
#
# [150 rows x 3 columns]

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.iloc[5]
# Out:
# sepal_length       5.4
# sepal_width        3.9
# petal_length       1.7
# petal_width        0.4
# species         setosa
# Name: 5, dtype: object

# %%
df.iloc[6:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
df.loc[df['species']=='aditya']
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []

# %%
df.loc[df['species']=='setosa']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.size
# Out:
# 750

# %%
df.shape
# Out:
# (150, 5)

# %%
df.ndim
# Out:
# 2

# %%
df.value_counts(df['species']=='setosa')
# Out:
# species
# False    100
# True      50
# Name: count, dtype: int64

# %%
df.value_counts(df['species']=='versicolor')
# Out:
# species
# False    100
# True      50
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.drop_duplicates("species")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 100           6.3          3.3           6.0          2.5   virginica

# %%
Sum=df['sepal_length'].sum()
Mean=df['sepal_length'].mean()
Median=df['sepal_length'].median()
Mode=df['sepal_length'].mode().iloc[0]
Skewness=df['sepal_length'].skew()
print('Sum : ',Sum)
print('Mean : ',Mean)
print('Median : ',Median)
print('Mode : ',Mode)
print('Skewness : ',Skewness)
# Out:
# Sum :  876.5
# Mean :  5.843333333333334
# Median :  5.8
# Mode :  5.0
# Skewness :  0.3149109566369728

# %%
(df['species']=='setosa').mean()
# Out:
# 0.3333333333333333

# %%
df['species'].max()
# Out:
# 'virginica'

# %%
df['species'].min()
# Out:
# 'setosa'

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['species_encoder']=encoder.fit_transform(df['species'])

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_encoder
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...

# %%
df['species_encoder'].unique()
# Out:
# array([0, 1, 2])

# %%
df['species_encoder'].nunique()
# Out:
# 3

# %%
df.value_counts(df['species_encoder'])
# Out:
# species_encoder
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
df['species'].replace(['setosa','virginica'],[0,1],inplace=True)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_4840\78971464.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['species'].replace(['setosa','virginica'],[0,1],inplace=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species  \
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       1
# 146           6.3          2.5           5.0          1.9       1
# 147           6.5          3.0           5.2          2.0       1
# 148           6.2          3.4           5.4          2.3       1
# 149           5.9          3.0           5.1          1.8       1
#
#      species_encoder
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# ...

# %%
df.dtypes
# Out:
# sepal_length       float64
# sepal_width        float64
# petal_length       float64
# petal_width        float64
# species             object
# species_encoder      int32
# dtype: object

# %%
df['species']=df['species'].astype('category')

# %%
df['sepal_length']=df['sepal_length'].astype('int')

# %%
df.dtypes
# Out:
# sepal_length          int32
# sepal_width         float64
# petal_length        float64
# petal_width         float64
# species            category
# species_encoder       int32
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sepal_length     150 non-null    int32
#  1   sepal_width      150 non-null    float64
#  2   petal_length     150 non-null    float64
#  3   petal_width      150 non-null    float64
#  4   species          150 non-null    category
#  5   species_encoder  150 non-null    int32
# dtypes: category(1), float64(3), int32(2)
# memory usage: 5.1 KB
