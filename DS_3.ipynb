# %%
import pandas as pd
df=pd.read_csv('adult.csv')
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
mean=df.groupby('sex')['age'].mean()

# %%
mean
# Out:
# sex
# Female    36.858230
# Male      39.433547
# Name: age, dtype: float64

# %%
median=df.groupby('race')['age'].median()
median
# Out:
# race
# Amer-Indian-Eskimo    35.0
# Asian-Pac-Islander    36.0
# Black                 36.0
# Other                 31.0
# White                 37.0
# Name: age, dtype: float64

# %%
min=df.groupby('race')['age'].min()
min
# Out:
# race
# Amer-Indian-Eskimo    17
# Asian-Pac-Islander    17
# Black                 17
# Other                 17
# White                 17
# Name: age, dtype: int64

# %%
max=df.groupby('race')['age'].max()
max
# Out:
# race
# Amer-Indian-Eskimo    82
# Asian-Pac-Islander    90
# Black                 90
# Other                 77
# White                 90
# Name: age, dtype: int64

# %%
std=df.groupby('race')['age'].std()
std
# Out:
# race
# Amer-Indian-Eskimo    12.447130
# Asian-Pac-Islander    12.825133
# Black                 12.759290
# Other                 11.538865
# White                 13.782306
# Name: age, dtype: float64

# %%
grouped_stats=df.groupby('sex')['age'].agg(['mean','median','std','min','max'])
grouped_stats
# Out:
#              mean  median        std  min  max
# sex
# Female  36.858230    35.0  14.013697   17   90
# Male    39.433547    38.0  13.370630   17   90

# %%
grouped_stats=df.groupby('sex')[['age','hours.per.week']].describe()
grouped_stats
# Out:
#             age                                                      \
#           count       mean        std   min   25%   50%   75%   max
# sex
# Female  10771.0  36.858230  14.013697  17.0  25.0  35.0  46.0  90.0
# Male    21790.0  39.433547  13.370630  17.0  29.0  38.0  48.0  90.0
#
#        hours.per.week
#                 count       mean        std  min   25%   50%   75%   max
# sex
# Female        10771.0  36.410361  11.811300  1.0  30.0  40.0  40.0  99.0
# Male          21790.0  42.428086  12.119755  1.0  40.0  40.0  49.0  99.0

# %%
import pandas as pd
iris=pd.read_csv('iris.csv')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
setosa=iris[iris['species']=='setosa']
virginica=iris[iris['species']=='virginica']
versicolor=iris[iris['species']=='versicolor']

setosa_stats=setosa.describe()
virginica_stats=virginica.describe()
versicolor_stats=versicolor.describe()

# %%
print("summary for setosa")
print(setosa_stats)
print("summary for virginica")
print(virginica_stats)
print("summary for versicolor")
print(versicolor_stats)
# Out:
# summary for setosa
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000
# summary for virginica
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# ...
